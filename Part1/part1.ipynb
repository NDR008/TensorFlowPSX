# %% [markdown]
# # Hypothesis
# I originally assumed that the low-res nature of the PSX would make it easier to process, since one of the reasons Pong and other games are easy to develop AI for is that the high contrast low resolution makes it easier to have clear borders to objects.

# %%
# just to find screen limits

screenXY = []

import pyautogui as py
import time
for i in range(0, 2):
    print("position", i+1)
    time.sleep(3)
    screenXY.append(py.position())
x1,y1 = screenXY[0]
x2,y2 = screenXY[1]
print(x1,y1,x2,y2)
# Out:
# position 1
# position 2
# 24 79 777 644

# %%
# Helper function for applying Canny Edge Detection

import cv2

def procImage(image):
    # convert to gray
    # processed_img = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    processed_img = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
    # blurr a bit
    processed_img = cv2.GaussianBlur(processed_img, (5, 5), 0)
    # process for edges
    processed_img = cv2.Canny(processed_img, threshold1=100, threshold2=200)
    
    return processed_img

# %%
# Main loop for screen grab and checking performance
# Using PIL

import numpy as np
from PIL import ImageGrab
import cv2
from time import process_time_ns, time

def screen_record_pil():
    last_time = time()
    while(True):
        printscreen = np.array(ImageGrab.grab(bbox=(x1, y1, x2, y2)))
        tmp_time = time()
        period = tmp_time - last_time
        print("time taken (ms)", period*1000, 
             "resulting in a frame rate of ", 1/((period)))
        last_time = tmp_time
        cv2.imshow('window', cv2.cvtColor(printscreen, cv2.COLOR_BGR2RGB))
        if cv2.waitKey(25) & 0xFF == ord('q'):
            cv2.destroyAllWindows()
            break


screen_record_pil()

# %%
# Main loop for screen grab and checking performance
# Using pyautogui

import numpy as np
import pyautogui
import cv2
from time import process_time_ns, time


def screen_record_py():
    last_time = time()
    while(True):
        printscreen = np.array(pyautogui.screenshot(region=(x1, y1, x2, y2)))
        tmp_time = time()
        period = tmp_time - last_time
        print("time taken (ms)", period*1000,
              "resulting in a frame rate of ", 1/((period)))
        last_time = tmp_time
        cv2.imshow('window', cv2.cvtColor(printscreen, cv2.COLOR_BGR2RGB))
        if cv2.waitKey(25) & 0xFF == ord('q'):
            cv2.destroyAllWindows()
            break


screen_record_py()

# %%
# Main loop for screen grab and checking performance
# Using mss

import numpy as np
import mss
import cv2
from time import time


def screen_record_mss():
    last_time = time() 
    while(True):
        with mss.mss() as sct:
            bbox = (x1, y1, x2, y2)
            printscreen = np.array(sct.grab(bbox))
        tmp_time = time() 
        period = tmp_time - last_time
        print("time taken (ms)", period*1000,
              "resulting in a frame rate of ", 1/((period)))
        last_time = tmp_time
        cv2.imshow('window', printscreen)
        if cv2.waitKey(25) & 0xFF == ord('q'):
            cv2.destroyAllWindows()
            break


screen_record_mss()
# Out:
# time taken (ms) 11.003255844116211 resulting in a frame rate of  90.88219106844922
# time taken (ms) 84.02538299560547 resulting in a frame rate of  11.901165628156674
# time taken (ms) 68.09115409851074 resulting in a frame rate of  14.686195486615661
# time taken (ms) 65.78302383422852 resulting in a frame rate of  15.201490319447364
# time taken (ms) 67.02637672424316 resulting in a frame rate of  14.91949958915658
# time taken (ms) 65.02509117126465 resulting in a frame rate of  15.378678937430106
# time taken (ms) 67.19088554382324 resulting in a frame rate of  14.882970984922947
# time taken (ms) 67.0006275177002 resulting in a frame rate of  14.925233345550689
# time taken (ms) 67.0161247253418 resulting in a frame rate of  14.921781945739026
# time taken (ms) 66.51163101196289 resulting in a frame rate of  15.03496433308241
# time taken (ms) 50.000667572021484 resulting in a frame rate of  19.99973297475658
# time taken (ms) 50.00019073486328 resulting in a frame rate of  19.999923706345726
# time taken (ms) 50.00162124633789 resulting in a frame rate of  19.99935152249168
# time taken (ms) 66.99490547180176 resulting in a frame rate of  14.926508112186252
# time taken (ms) 66.43033027648926 resulting in a frame rate of  15.053364868696367
# time taken (ms) 66.99681282043457 resulting in a frame rate of  14.926083165779968
# time taken (ms) 50.0025749206543 resulting in a frame rate of  19.99897008477728
# time taken (ms) 66.42484664916992 resulting in a frame rate of  15.054607582033409
# time taken (ms) 65.99926948547363 resulting in a frame rate of  15.15168285643069
# time taken (ms) 51.62954330444336 resulting in a frame rate of  19.368755483722005
# time taken (ms) 49.013614654541016 resulting in a frame rate of  20.402494430337878
# time taken (ms) 66.88189506530762 resulting in a frame rate of  14.951729448209237
# time taken (ms) 66.31588935852051 resulting in a frame rate of  15.079342366860928
# time taken (ms) 436.89513206481934 resulting in a frame rate of  2.2888787871677096
# time taken (ms) 68.6488151550293 resulting in a frame rate of  14.56689380205186
# time taken (ms) 65.26827812194824 resulting in a frame rate of  15.321378604956987
# time taken (ms) 66.03002548217773 resulting in a frame rate of  15.144625383643257
# time taken (ms) 65.8118724822998 resulting in a frame rate of  15.19482674298549
# time taken (ms) 66.02931022644043 resulting in a frame rate of  15.144789436245924
# time taken (ms) 66.02025032043457 resulting in a frame rate of  15.146867743554742
# time taken (ms) 50.04262924194336 resulting in a frame rate of  19.982962828856472
# time taken (ms) 66.18046760559082 resulting in a frame rate of  15.110198464592317
# time taken (ms) 66.99299812316895 resulting in a frame rate of  14.926933082789718
# time taken (ms) 67.0309066772461 resulting in a frame rate of  14.91849132841066
# time taken (ms) 66.4217472076416 resulting in a frame rate of  15.055310075988988
# time taken (ms) 67.14701652526855 resulting in a frame rate of  14.892694444937597
# time taken (ms) 66.22314453125 resulting in a frame rate of  15.100460829493088
# time taken (ms) 66.73574447631836 resulting in a frame rate of  14.984473580793827
# time taken (ms) 50.99964141845703 resulting in a frame rate of  19.607981001178075
# time taken (ms) 67.0020580291748 resulting in a frame rate of  14.92491468791255
# time taken (ms) 66.06554985046387 resulting in a frame rate of  15.136481907188406
# time taken (ms) 49.19576644897461 resulting in a frame rate of  20.326952341258686
# time taken (ms) 50.009965896606445 resulting in a frame rate of  19.996014435751846
# time taken (ms) 67.9938793182373 resulting in a frame rate of  14.707206148947883
# time taken (ms) 48.86746406555176 resulting in a frame rate of  20.463513282755592
# time taken (ms) 51.531314849853516 resulting in a frame rate of  19.405676003294193
# time taken (ms) 66.29276275634766 resulting in a frame rate of  15.084602880036828
# time taken (ms) 82.72552490234375 resulting in a frame rate of  12.088167481324357
# time taken (ms) 50.1408576965332 resulting in a frame rate of  19.94381520260953
# time taken (ms) 66.88809394836426 resulting in a frame rate of  14.950343790211335
# time taken (ms) 50.00019073486328 resulting in a frame rate of  19.999923706345726
# time taken (ms) 66.99967384338379 resulting in a frame rate of  14.925445791535743
# time taken (ms) 66.95866584777832 resulting in a frame rate of  14.934586693727857
# time taken (ms) 65.9942626953125 resulting in a frame rate of  15.152832369942196
# time taken (ms) 49.999237060546875 resulting in a frame rate of  20.000305180437934
# time taken (ms) 67.00277328491211 resulting in a frame rate of  14.924755364195994
# time taken (ms) 68.63093376159668 resulting in a frame rate of  14.57068912210492
# time taken (ms) 65.02795219421387 resulting in a frame rate of  15.378002324498528
# time taken (ms) 67.06118583679199 resulting in a frame rate of  14.911755399520043
# time taken (ms) 67.91090965270996 resulting in a frame rate of  14.725174572302247
# time taken (ms) 65.83857536315918 resulting in a frame rate of  15.188664008662053
# time taken (ms) 65.27209281921387 resulting in a frame rate of  15.320483177546198
# time taken (ms) 69.01097297668457 resulting in a frame rate of  14.49044922664474
# time taken (ms) 66.1468505859375 resulting in a frame rate of  15.117877739331027
# time taken (ms) 83.50563049316406 resulting in a frame rate of  11.97524040108723
# time taken (ms) 66.2386417388916 resulting in a frame rate of  15.096927922253217
# time taken (ms) 67.0468807220459 resulting in a frame rate of  14.914936969934036
# time taken (ms) 65.23609161376953 resulting in a frame rate of  15.328937943132813
# time taken (ms) 501.7507076263428 resulting in a frame rate of  1.9930216037576711
# time taken (ms) 67.0766830444336 resulting in a frame rate of  14.908310229615411
# time taken (ms) 82.99803733825684 resulting in a frame rate of  12.04847767573732
# time taken (ms) 66.59722328186035 resulting in a frame rate of  15.015641054097498
# time taken (ms) 50.43482780456543 resulting in a frame rate of  19.8275684389167
# time taken (ms) 49.26109313964844 resulting in a frame rate of  20.299996128083013
# time taken (ms) 67.35515594482422 resulting in a frame rate of  14.846673368541776
# time taken (ms) 67.08502769470215 resulting in a frame rate of  14.906455797423368
# time taken (ms) 65.21844863891602 resulting in a frame rate of  15.333084746258399
# time taken (ms) 67.99507141113281 resulting in a frame rate of  14.706948301495133
# time taken (ms) 66.8036937713623 resulting in a frame rate of  14.969232141901175
# time taken (ms) 51.01156234741211 resulting in a frame rate of  19.603398797894915
# time taken (ms) 49.00169372558594 resulting in a frame rate of  20.40745786462185
# time taken (ms) 67.19589233398438 resulting in a frame rate of  14.881862049389724
# time taken (ms) 82.47995376586914 resulting in a frame rate of  12.124158105600296
# time taken (ms) 67.44074821472168 resulting in a frame rate of  14.82783074731234
# time taken (ms) 50.072431564331055 resulting in a frame rate of  19.97106928420762
# time taken (ms) 50.01354217529297 resulting in a frame rate of  19.994584596609652
# time taken (ms) 66.01476669311523 resulting in a frame rate of  15.148125943529106
# time taken (ms) 67.98768043518066 resulting in a frame rate of  14.708547101461981
# time taken (ms) 65.43850898742676 resulting in a frame rate of  15.28152177477238
# time taken (ms) 50.498247146606445 resulting in a frame rate of  19.802667547980455
# time taken (ms) 66.41459465026855 resulting in a frame rate of  15.05693146613154
# time taken (ms) 68.30167770385742 resulting in a frame rate of  14.64092879732475
# time taken (ms) 65.01889228820801 resulting in a frame rate of  15.380145136390805
# time taken (ms) 50.01401901245117 resulting in a frame rate of  19.994393966840505
# time taken (ms) 67.0163631439209 resulting in a frame rate of  14.92172885974805
# time taken (ms) 67.67678260803223 resulting in a frame rate of  14.77611614298749
# time taken (ms) 65.56177139282227 resulting in a frame rate of  15.252791051180788
# time taken (ms) 50.087928771972656 resulting in a frame rate of  19.964890234382437
# time taken (ms) 66.55502319335938 resulting in a frame rate of  15.025161918954549
# time taken (ms) 71.46167755126953 resulting in a frame rate of  13.993514206024049
# time taken (ms) 63.56644630432129 resulting in a frame rate of  15.731570004913415
# time taken (ms) 70.50013542175293 resulting in a frame rate of  14.184369916705839

# %%
# Main loop for mms
# And add Canny Edge 

import numpy as np
import mss
import cv2
from time import time


def screen_record_mss():
    last_time = time()
    while(True):
        with mss.mss() as sct:
            bbox = (x1, y1, x2, y2)
            printscreen = np.array(sct.grab(bbox))
        result = procImage(printscreen)
        tmp_time = time() 
        period = tmp_time - last_time
        print("time taken (ms)", period*1000,
              "resulting in a frame rate of ", 1/((period)))
        last_time = tmp_time
        cv2.imshow('window', result)
        if cv2.waitKey(25) & 0xFF == ord('q'):
            cv2.destroyAllWindows()
            break


screen_record_mss()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# j:\git\TensorFlowPSX\Part1\part1.ipynb Cell 7' in <cell line: 28>()
#      <a href='vscode-notebook-cell:/j%3A/git/TensorFlowPSX/Part1/part1.ipynb#ch0000006?line=23'>24</a>             cv2.destroyAllWindows()
#      <a href='vscode-notebook-cell:/j%3A/git/TensorFlowPSX/Part1/part1.ipynb#ch0000006?line=24'>25</a>             break
# ---> <a href='vscode-notebook-cell:/j%3A/git/TensorFlowPSX/Part1/part1.ipynb#ch0000006?line=27'>28</a> screen_record_mss()
#
# j:\git\TensorFlowPSX\Part1\part1.ipynb Cell 7' in screen_record_mss()
#      <a href='vscode-notebook-cell:/j%3A/git/TensorFlowPSX/Part1/part1.ipynb#ch0000006?line=13'>14</a>     bbox = (x1, y1, x2, y2)
#      <a href='vscode-notebook-cell:/j%3A/git/TensorFlowPSX/Part1/part1.ipynb#ch0000006?line=14'>15</a>     printscreen = np.array(sct.grab(bbox))
# ---> <a href='vscode-notebook-cell:/j%3A/git/TensorFlowPSX/Part1/part1.ipynb#ch0000006?line=15'>16</a> result = procImage(printscreen)
#      <a href='vscode-notebook-cell:/j%3A/git/TensorFlowPSX/Part1/part1.ipynb#ch0000006?line=16'>17</a> tmp_time = time()
#      <a href='vscode-notebook-cell:/j%3A/git/TensorFlowPSX/Part1/part1.ipynb#ch0000006?line=17'>18</a> period = tmp_time - last_time
#
# NameError: name 'procImage' is not defined

# %%
# Main loop for screen grab and checking performance
# Using d3dshot

import numpy as np
import d3dshot
import cv2
from time import time



def screen_record_d3dshot_sc():
    screen_buffer = d3dshot.create(
        capture_output="numpy")
    screen_buffer.display = screen_buffer.displays[0]
    last_time = time() - 5
    while(True):
        printscreen = screen_buffer.screenshot(region=(x1, y1, x2, y2))
        tmp_time = time()
        period = tmp_time - last_time
        # print("time taken (ms)", period*1000,
        #      "resulting in a frame rate of ", 1/((period)))
        last_time = tmp_time
        cv2.imshow('window', cv2.cvtColor(printscreen, cv2.COLOR_BGR2RGB))
        if cv2.waitKey(25) & 0xFF == ord('q'):
            cv2.destroyAllWindows()
            break
    screen_buffer.stop()


def screen_record_d3dshot_buff():
    screen_buffer = d3dshot.create(
        capture_output="numpy", frame_buffer_size=20)
    screen_buffer.display = screen_buffer.displays[0]
    screen_buffer.capture(region=(x1, y1, x2, y2))
    last_time = time() - 5
    while(True):
        printscreen = screen_buffer.get_latest_frame()
        tmp_time = time()
        period = tmp_time - last_time
        print("time taken (ms)", period*1000,
              "resulting in a frame rate of ", 1/((period)))
        last_time = tmp_time
        cv2.imshow('window', cv2.cvtColor(printscreen, cv2.COLOR_BGR2RGB))
        if cv2.waitKey(25) & 0xFF == ord('q'):
            cv2.destroyAllWindows()
            break
    screen_buffer.stop()


screen_record_d3dshot_buff()
screen_record_d3dshot_sc()
# Out:
# Only 1 instance of D3DShot is allowed per process! Returning the existing instance...
# time taken (ms) 5000.0 resulting in a frame rate of  0.2
# time taken (ms) 120.99719047546387 resulting in a frame rate of  8.26465470867923
# time taken (ms) 57.00230598449707 resulting in a frame rate of  17.54314992575862
# time taken (ms) 60.002803802490234 resulting in a frame rate of  16.665887869034847
# time taken (ms) 59.99565124511719 resulting in a frame rate of  16.667874741694483
# time taken (ms) 59.00073051452637 resulting in a frame rate of  16.948942687307802
# time taken (ms) 56.006669998168945 resulting in a frame rate of  17.855016197761685
# time taken (ms) 58.00819396972656 resulting in a frame rate of  17.238943872686022
# time taken (ms) 60.00161170959473 resulting in a frame rate of  16.66621898158266
# time taken (ms) 57.01041221618652 resulting in a frame rate of  17.540655489526134
# time taken (ms) 56.51688575744629 resulting in a frame rate of  17.693827014667853
# time taken (ms) 58.74323844909668 resulting in a frame rate of  17.023235803837053
# time taken (ms) 57.0218563079834 resulting in a frame rate of  17.53713513988134
# time taken (ms) 62.537431716918945 resulting in a frame rate of  15.990423216076188
# time taken (ms) 60.990333557128906 resulting in a frame rate of  16.396040842493708
# time taken (ms) 58.13336372375488 resulting in a frame rate of  17.201825869769387
# time taken (ms) 56.00094795227051 resulting in a frame rate of  17.85684058156119
# time taken (ms) 60.009002685546875 resulting in a frame rate of  16.66416629584896
# time taken (ms) 60.95695495605469 resulting in a frame rate of  16.40501893050471
# time taken (ms) 59.00001525878906 resulting in a frame rate of  16.949148158924125
# time taken (ms) 61.876773834228516 resulting in a frame rate of  16.161152853234693
# time taken (ms) 57.16991424560547 resulting in a frame rate of  17.49171768395416
# time taken (ms) 58.83049964904785 resulting in a frame rate of  16.997985840091104
# time taken (ms) 59.000253677368164 resulting in a frame rate of  16.949079667831814
# time taken (ms) 62.50739097595215 resulting in a frame rate of  15.998108133880041
# time taken (ms) 63.0190372467041 resulting in a frame rate of  15.86822083754223
# time taken (ms) 107.46455192565918 resulting in a frame rate of  9.305394030691819
# time taken (ms) 57.9986572265625 resulting in a frame rate of  17.24177847934754
# time taken (ms) 59.89980697631836 resulting in a frame rate of  16.694544615066192
# time taken (ms) 59.32497978210449 resulting in a frame rate of  16.856305786751438
# time taken (ms) 57.00874328613281 resulting in a frame rate of  17.541168991936832
# time taken (ms) 56.76150321960449 resulting in a frame rate of  17.617574293814975
# time taken (ms) 59.010982513427734 resulting in a frame rate of  16.945998141489234
# time taken (ms) 57.201385498046875 resulting in a frame rate of  17.48209403134378
# time taken (ms) 689.0676021575928 resulting in a frame rate of  1.4512364198647894
# time taken (ms) 58.736324310302734 resulting in a frame rate of  17.02523969183059
# time taken (ms) 64.01658058166504 resulting in a frame rate of  15.620953054877935
# time taken (ms) 106.1704158782959 resulting in a frame rate of  9.418819656374984
# time taken (ms) 58.94899368286133 resulting in a frame rate of  16.963817997977756
# time taken (ms) 69.06628608703613 resulting in a frame rate of  14.478844261870652
# time taken (ms) 59.00883674621582 resulting in a frame rate of  16.94661435711371
# time taken (ms) 58.10832977294922 resulting in a frame rate of  17.2092366775533
# time taken (ms) 58.992624282836914 resulting in a frame rate of  16.95127165737796
# time taken (ms) 58.028459548950195 resulting in a frame rate of  17.232923427106403
# time taken (ms) 114.07899856567383 resulting in a frame rate of  8.765855350880493
# time taken (ms) 59.546470642089844 resulting in a frame rate of  16.793606560002562
# time taken (ms) 57.28578567504883 resulting in a frame rate of  17.456337348194143
# time taken (ms) 58.60781669616699 resulting in a frame rate of  17.062570427835116
# time taken (ms) 54.456472396850586 resulting in a frame rate of  18.363290091809795
# time taken (ms) 57.65175819396973 resulting in a frame rate of  17.345524773685018
# time taken (ms) 58.33625793457031 resulting in a frame rate of  17.141997711296387
# time taken (ms) 63.24577331542969 resulting in a frame rate of  15.811333273017883
# time taken (ms) 107.7260971069336 resulting in a frame rate of  9.282801724519516
# time taken (ms) 69.02265548706055 resulting in a frame rate of  14.487996628693411
# time taken (ms) 57.003021240234375 resulting in a frame rate of  17.54292979990631
# time taken (ms) 57.602643966674805 resulting in a frame rate of  17.360314234508678
# time taken (ms) 57.40785598754883 resulting in a frame rate of  17.419218725341175
# time taken (ms) 59.848785400390625 resulting in a frame rate of  16.708776850022307
# time taken (ms) 57.78789520263672 resulting in a frame rate of  17.3046621008334
# time taken (ms) 57.335615158081055 resulting in a frame rate of  17.441166319448776
# time taken (ms) 58.05015563964844 resulting in a frame rate of  17.226482667980942
# time taken (ms) 63.61651420593262 resulting in a frame rate of  15.719188837711327
# time taken (ms) 53.38788032531738 resulting in a frame rate of  18.730842916154963
# time taken (ms) 56.53095245361328 resulting in a frame rate of  17.689424228621558
# time taken (ms) 56.42509460449219 resulting in a frame rate of  17.72261095899672
# time taken (ms) 55.999040603637695 resulting in a frame rate of  17.85744879234663
# time taken (ms) 62.03126907348633 resulting in a frame rate of  16.120901844122102
# time taken (ms) 114.98069763183594 resulting in a frame rate of  8.697111955277608
# time taken (ms) 59.00168418884277 resulting in a frame rate of  16.948668732902036
# time taken (ms) 59.58867073059082 resulting in a frame rate of  16.78171349921779
# time taken (ms) 55.41205406188965 resulting in a frame rate of  18.046614891465698
# time taken (ms) 57.4343204498291 resulting in a frame rate of  17.411192335313434
# time taken (ms) 60.18495559692383 resulting in a frame rate of  16.615447998288662
# time taken (ms) 58.96282196044922 resulting in a frame rate of  16.959839552299158
# time taken (ms) 56.43343925476074 resulting in a frame rate of  17.71999036751317
# time taken (ms) 56.99467658996582 resulting in a frame rate of  17.545498278624404
# time taken (ms) 58.00318717956543 resulting in a frame rate of  17.24043192495982
# time taken (ms) 59.041738510131836 resulting in a frame rate of  16.937170639519625
# time taken (ms) 56.96272850036621 resulting in a frame rate of  17.555338838685916
# time taken (ms) 57.4345588684082 resulting in a frame rate of  17.411120059112154
# time taken (ms) 57.02972412109375 resulting in a frame rate of  17.534715719063545
# time taken (ms) 58.09521675109863 resulting in a frame rate of  17.21312107818393
# time taken (ms) 59.45944786071777 resulting in a frame rate of  16.818185098900923
# time taken (ms) 56.993722915649414 resulting in a frame rate of  17.545791866939414
# time taken (ms) 56.99968338012695 resulting in a frame rate of  17.5439571011486
# time taken (ms) 56.513071060180664 resulting in a frame rate of  17.69502136833268
# time taken (ms) 59.02981758117676 resulting in a frame rate of  16.940591060184417
# time taken (ms) 56.00333213806152 resulting in a frame rate of  17.856080376338365
# time taken (ms) 56.0307502746582 resulting in a frame rate of  17.84734266626952
# time taken (ms) 62.46685981750488 resulting in a frame rate of  16.00848838762619
# time taken (ms) 60.826778411865234 resulting in a frame rate of  16.440127623213627
# time taken (ms) 58.4721565246582 resulting in a frame rate of  17.102156982670746
# time taken (ms) 58.183908462524414 resulting in a frame rate of  17.18688253203355
# time taken (ms) 59.0364933013916 resulting in a frame rate of  16.938675454431642
# time taken (ms) 61.01822853088379 resulting in a frame rate of  16.38854526059962
# time taken (ms) 56.44369125366211 resulting in a frame rate of  17.716771844455145
# time taken (ms) 62.00242042541504 resulting in a frame rate of  16.128402619425742
# time taken (ms) 57.49344825744629 resulting in a frame rate of  17.39328619710133
# time taken (ms) 62.50905990600586 resulting in a frame rate of  15.99768100022122
# time taken (ms) 60.00018119812012 resulting in a frame rate of  16.666616334007525
# time taken (ms) 62.36124038696289 resulting in a frame rate of  16.035601501747195
# time taken (ms) 113.00897598266602 resulting in a frame rate of  8.848854626851816
# time taken (ms) 59.999704360961914 resulting in a frame rate of  16.666748789026332
# time taken (ms) 57.13963508605957 resulting in a frame rate of  17.50098681053655
# time taken (ms) 57.00874328613281 resulting in a frame rate of  17.541168991936832
# time taken (ms) 58.00747871398926 resulting in a frame rate of  17.239156435855175
# time taken (ms) 57.825326919555664 resulting in a frame rate of  17.293460379241104
# time taken (ms) 58.011531829833984 resulting in a frame rate of  17.237951980535758
# time taken (ms) 56.99801445007324 resulting in a frame rate of  17.544470796889573
# time taken (ms) 55.9999942779541 resulting in a frame rate of  17.857144681775026
# time taken (ms) 58.012962341308594 resulting in a frame rate of  17.23752691884072
# time taken (ms) 58.005332946777344 resulting in a frame rate of  17.239794156815677
# time taken (ms) 60.00232696533203 resulting in a frame rate of  16.666020312475165
# time taken (ms) 58.11262130737305 resulting in a frame rate of  17.207965799903175
# time taken (ms) 55.00006675720215 resulting in a frame rate of  18.18179611334839
# time taken (ms) 58.00819396972656 resulting in a frame rate of  17.238943872686022
# time taken (ms) 61.22565269470215 resulting in a frame rate of  16.333023103672524
# time taken (ms) 53.99942398071289 resulting in a frame rate of  18.51871605810411
# time taken (ms) 58.00747871398926 resulting in a frame rate of  17.239156435855175
# time taken (ms) 57.997941970825195 resulting in a frame rate of  17.24199111242657
# time taken (ms) 57.99984931945801 resulting in a frame rate of  17.241424102536698
# time taken (ms) 59.00001525878906 resulting in a frame rate of  16.949148158924125
# time taken (ms) 54.99982833862305 resulting in a frame rate of  18.181874929557928
# time taken (ms) 55.9999942779541 resulting in a frame rate of  17.857144681775026
# time taken (ms) 60.00089645385742 resulting in a frame rate of  16.666417655426724
# time taken (ms) 56.999921798706055 resulting in a frame rate of  17.54388371849838
# time taken (ms) 55.9995174407959 resulting in a frame rate of  17.857296735766074
# time taken (ms) 55.742502212524414 resulting in a frame rate of  17.939632422444728
# time taken (ms) 58.54296684265137 resulting in a frame rate of  17.081471164379934
# time taken (ms) 60.999393463134766 resulting in a frame rate of  16.39360562829783
# time taken (ms) 57.05451965332031 resulting in a frame rate of  17.527095242870992
# time taken (ms) 57.000160217285156 resulting in a frame rate of  17.543810336462045
# time taken (ms) 61.003923416137695 resulting in a frame rate of  16.392388292446526
# time taken (ms) 56.00309371948242 resulting in a frame rate of  17.85615639394791
# time taken (ms) 56.00118637084961 resulting in a frame rate of  17.85676455812607
# time taken (ms) 62.99924850463867 resulting in a frame rate of  15.873205216509358
# time taken (ms) 109.0080738067627 resulting in a frame rate of  9.173632420775437
# time taken (ms) 63.01093101501465 resulting in a frame rate of  15.870262252778229
# time taken (ms) 109.36832427978516 resulting in a frame rate of  9.143415212633304
# time taken (ms) 57.07716941833496 resulting in a frame rate of  17.520140017293304
# time taken (ms) 58.939456939697266 resulting in a frame rate of  16.96656284130901
# time taken (ms) 57.00850486755371 resulting in a frame rate of  17.541242351878417
# time taken (ms) 58.008670806884766 resulting in a frame rate of  17.23880216681874
# time taken (ms) 58.008670806884766 resulting in a frame rate of  17.23880216681874
# time taken (ms) 61.00964546203613 resulting in a frame rate of  16.390850863446833
# time taken (ms) 58.00151824951172 resulting in a frame rate of  17.240927999473847
# time taken (ms) 57.51347541809082 resulting in a frame rate of  17.387229561951507
# time taken (ms) 56.5340518951416 resulting in a frame rate of  17.6884544177867
# time taken (ms) 58.524370193481445 resulting in a frame rate of  17.08689895669107
# time taken (ms) 57.57927894592285 resulting in a frame rate of  17.367358853853958
# time taken (ms) 62.45160102844238 resulting in a frame rate of  16.012399738872496
# time taken (ms) 111.01460456848145 resulting in a frame rate of  9.007823825406064
# time taken (ms) 63.512325286865234 resulting in a frame rate of  15.74497541198994
# time taken (ms) 108.48236083984375 resulting in a frame rate of  9.218088473169702
# time taken (ms) 63.00520896911621 resulting in a frame rate of  15.871703568036388
# time taken (ms) 53.51758003234863 resulting in a frame rate of  18.685448770208804
# time taken (ms) 59.99875068664551 resulting in a frame rate of  16.66701370538003
# time taken (ms) 58.005332946777344 resulting in a frame rate of  17.239794156815677
# time taken (ms) 57.02352523803711 resulting in a frame rate of  17.536621873615026
# time taken (ms) 59.47089195251465 resulting in a frame rate of  16.814948744983745
# time taken (ms) 58.51173400878906 resulting in a frame rate of  17.090589040649345
# time taken (ms) 66.17069244384766 resulting in a frame rate of  15.112430640628379
# time taken (ms) 57.79552459716797 resulting in a frame rate of  17.30237777007739
# time taken (ms) 59.237003326416016 resulting in a frame rate of  16.881340105772406
# time taken (ms) 57.773590087890625 resulting in a frame rate of  17.308946847144274
# time taken (ms) 55.99808692932129 resulting in a frame rate of  17.857752913276535
# time taken (ms) 59.01598930358887 resulting in a frame rate of  16.944560479293504
# time taken (ms) 59.0212345123291 resulting in a frame rate of  16.943054618606926
# time taken (ms) 55.00364303588867 resulting in a frame rate of  18.180613952198073
# time taken (ms) 57.016611099243164 resulting in a frame rate of  17.538748458048463
# time taken (ms) 64.00775909423828 resulting in a frame rate of  15.623105919513685
# time taken (ms) 108.01959037780762 resulting in a frame rate of  9.257580004723364
# time taken (ms) 58.03394317626953 resulting in a frame rate of  17.23129508816328
# time taken (ms) 58.008670806884766 resulting in a frame rate of  17.23880216681874
# time taken (ms) 63.87758255004883 resulting in a frame rate of  15.654944349474848
# time taken (ms) 58.99238586425781 resulting in a frame rate of  16.951340166187073
# time taken (ms) 58.999061584472656 resulting in a frame rate of  16.949422128828903
# time taken (ms) 57.01637268066406 resulting in a frame rate of  17.538821797745292
# time taken (ms) 60.04786491394043 resulting in a frame rate of  16.653381455496923
# time taken (ms) 62.54076957702637 resulting in a frame rate of  15.989569792043916
# time taken (ms) 58.53009223937988 resulting in a frame rate of  17.085228499386947
# time taken (ms) 58.00652503967285 resulting in a frame rate of  17.23943986156837
# time taken (ms) 59.541940689086914 resulting in a frame rate of  16.794884218197545
# time taken (ms) 57.878732681274414 resulting in a frame rate of  17.277503388106
# time taken (ms) 55.00984191894531 resulting in a frame rate of  18.17856523698901
# time taken (ms) 61.00153923034668 resulting in a frame rate of  16.39302897298903
# time taken (ms) 54.99553680419922 resulting in a frame rate of  18.183293738186485
# time taken (ms) 57.007789611816406 resulting in a frame rate of  17.541462435384847
# time taken (ms) 57.99722671508789 resulting in a frame rate of  17.24220375075023
# time taken (ms) 56.01382255554199 resulting in a frame rate of  17.8527362421735
# time taken (ms) 59.98992919921875 resulting in a frame rate of  16.66946458094875
# time taken (ms) 56.55264854431152 resulting in a frame rate of  17.682637785150863
# time taken (ms) 56.458473205566406 resulting in a frame rate of  17.71213324099255
# time taken (ms) 55.99546432495117 resulting in a frame rate of  17.85858929924807
# time taken (ms) 60.51516532897949 resulting in a frame rate of  16.52478340864947
# time taken (ms) 58.90798568725586 resulting in a frame rate of  16.975627129894203
# time taken (ms) 56.5800666809082 resulting in a frame rate of  17.67406895505533
# time taken (ms) 58.00509452819824 resulting in a frame rate of  17.239865017612654
# time taken (ms) 56.52356147766113 resulting in a frame rate of  17.691737283667333
# time taken (ms) 59.48448181152344 resulting in a frame rate of  16.81110719209927
# time taken (ms) 57.1284294128418 resulting in a frame rate of  17.504419608203193
# time taken (ms) 57.007789611816406 resulting in a frame rate of  17.541462435384847
# time taken (ms) 57.00111389160156 resulting in a frame rate of  17.543516814455412
# time taken (ms) 58.998823165893555 resulting in a frame rate of  16.949490622689012
# time taken (ms) 57.001352310180664 resulting in a frame rate of  17.543443435488392
# time taken (ms) 56.99944496154785 resulting in a frame rate of  17.544030484412712
# time taken (ms) 55.9995174407959 resulting in a frame rate of  17.857296735766074
# time taken (ms) 63.00210952758789 resulting in a frame rate of  15.872484389782404
# time taken (ms) 63.997745513916016 resulting in a frame rate of  15.625550431031272
# time taken (ms) 53.999900817871094 resulting in a frame rate of  18.51855253165675
# time taken (ms) 56.00118637084961 resulting in a frame rate of  17.85676455812607
# time taken (ms) 58.998823165893555 resulting in a frame rate of  16.949490622689012
# time taken (ms) 58.00127983093262 resulting in a frame rate of  17.240998869592026
# Only 1 instance of D3DShot is allowed per process! Returning the existing instance...
