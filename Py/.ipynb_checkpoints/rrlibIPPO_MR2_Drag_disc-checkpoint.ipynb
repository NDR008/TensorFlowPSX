# %% [markdown]
# # Initial AI Agent PPO w/o
# NN (working) MR2 Drag Disc

# %%
import torch

if torch.cuda.is_available():
    print("GPU is available")
else:
    print("GPU is not available")
# Out:
# GPU is available

# %%
from myRTClass import MyGranTurismoRTGYM, DEFAULT_CONFIG_DICT
import numpy as np
import gymnasium
from time import sleep

my_config = DEFAULT_CONFIG_DICT
my_config["interface"] = MyGranTurismoRTGYM
my_config["time_step_duration"] = 0.05
my_config["start_obs_capture"] = 0.05
my_config["time_step_timeout_factor"] = 1.0
my_config["ep_max_length"] = 384
my_config["act_buf_len"] = 4
my_config["reset_act_buf"] = True
my_config["benchmark"] = False
my_config["benchmark_polyak"] = 0.2

my_config["interface_kwargs"] = {
  'debugFlag': False, # do not use render() while True
  'discreteAccel' : True,
  'accelAndBrake' : False,
  'discSteer' : True,
  'contAccelOnly' : False,
  'discAccelOnly' : False,
  'modelMode': 13,
  #  [42, 42, K], [84, 84, K], [10, 10, K], [240, 320, K] and  [480, 640, K]
  'imageWidth' : 42, # there is a default Cov layer for PPO with 240 x 320
  'imageHeight' : 42,
  'trackChoice' : 1, # 0 is HS, 1 is 400m
  'carChoice' : 0, # 0 is MR2, 1 is Supra, 2 is Civic
  'rewardMode' : "complex"
}

# %%
def env_creator(env_config):
    env = gymnasium.make("real-time-gym-v1", config=env_config)
    return env  # return an env instance

from ray.tune.registry import register_env
register_env("gt-rtgym-env-v1", lambda config: env_creator(my_config)) # better way

# %%
import ray
ray.shutdown()
ray.init()
# Out:
# 2023-10-20 11:04:57,822	INFO worker.py:1616 -- Started a local Ray instance. View the dashboard at 127.0.0.1:8265
# RayContext(dashboard_url='127.0.0.1:8265', python_version='3.9.9', ray_version='2.4.0', ray_commit='4479f66d4db967d3c9dd0af2572061276ba926ba', address_info={'node_ip_address': '127.0.0.1', 'raylet_ip_address': '127.0.0.1', 'redis_address': None, 'object_store_address': 'tcp://127.0.0.1:65168', 'raylet_socket_name': 'tcp://127.0.0.1:50962', 'webui_url': '127.0.0.1:8265', 'session_dir': 'C:\\Users\\nadir\\AppData\\Local\\Temp\\ray\\session_2023-10-20_11-04-55_116943_13744', 'metrics_export_port': 56363, 'gcs_address': '127.0.0.1:59288', 'address': '127.0.0.1:59288', 'dashboard_agent_listen_port': 52365, 'node_id': '8fe9a714ed92306e09db8be8d6717c2280892f4562ee7c52a7829791'})

# %%
from ray.rllib.algorithms.ppo import PPOConfig
config = (
    PPOConfig()
    .resources(
        num_gpus=1
        )
    .rollouts(
        num_rollout_workers=1,
        enable_connectors=True,
        batch_mode="truncate_episodes",
        #batch_mode="completed_episodes",
        )
    .framework(
        framework="torch",
        )
    .environment(
        env="gt-rtgym-env-v1",
        disable_env_checking=True,
        render_env=False,
        )
    .training(
        train_batch_size=384,
        lr=0.0001,
        )
)

# %%
import json

class CustomEncoder(json.JSONEncoder):
    def default(self, obj):
        try:
            json.dumps(obj)
        except TypeError:
            return "Not serializable object!"
        return obj

config_dict = config.to_dict()

print(json.dumps(config_dict, sort_keys=True, indent=4, cls=CustomEncoder))
# Out:
# {
#     "_disable_action_flattening": false,
#     "_disable_execution_plan_api": true,
#     "_disable_preprocessor_api": false,
#     "_enable_learner_api": false,
#     "_enable_rl_module_api": false,
#     "_fake_gpus": false,
#     "_learner_hps": "Not serializable object!",
#     "_tf_policy_handles_more_than_one_loss": false,
#     "_validate_exploration_conf_and_rl_modules": true,
#     "action_space": null,
#     "actions_in_input_normalized": false,
#     "always_attach_evaluation_results": false,
#     "auto_wrap_old_gym_envs": true,
#     "batch_mode": "truncate_episodes",
#     "callbacks": "Not serializable object!",
#     "checkpoint_trainable_policies_only": false,
#     "clip_actions": false,
#     "clip_param": 0.3,
#     "clip_rewards": null,
#     "compress_observations": false,
#     "create_env_on_driver": false,
#     "custom_eval_function": null,
#     "custom_resources_per_worker": {},
#     "delay_between_worker_restarts_s": 60.0,
#     "disable_env_checking": true,
#     "eager_max_retraces": 20,
#     "eager_tracing": false,
#     "enable_async_evaluation": false,
#     "enable_connectors": true,
#     "enable_tf1_exec_eagerly": false,
#     "entropy_coeff": 0.0,
#     "entropy_coeff_schedule": null,
#     "env": "gt-rtgym-env-v1",
#     "env_config": {},
#     "env_task_fn": null,
#     "evaluation_config": null,
#     "evaluation_duration": 10,
#     "evaluation_duration_unit": "episodes",
#     "evaluation_interval": null,
#     "evaluation_num_workers": 0,
#     "evaluation_parallel_to_training": false,
#     "evaluation_sample_timeout_s": 180.0,
#     "exploration_config": {
#         "type": "StochasticSampling"
#     },
#     "explore": true,
#     "export_native_model_files": false,
#     "extra_python_environs_for_driver": {},
#     "extra_python_environs_for_worker": {},
#     "fake_sampler": false,
#     "framework": "torch",
#     "gamma": 0.99,
#     "grad_clip": null,
#     "horizon": -1,
#     "ignore_worker_failures": false,
#     "in_evaluation": false,
#     "input": "sampler",
#     "input_config": {},
#     "is_atari": null,
#     "keep_per_episode_custom_metrics": false,
#     "kl_coeff": 0.2,
#     "kl_target": 0.01,
#     "lambda": 1.0,
#     "learner_class": null,
#     "local_gpu_idx": 0,
#     "local_tf_session_args": {
#         "inter_op_parallelism_threads": 8,
#         "intra_op_parallelism_threads": 8
#     },
#     "log_level": "WARN",
#     "log_sys_usage": true,
#     "logger_config": null,
#     "logger_creator": null,
#     "lr": 0.0001,
#     "lr_schedule": null,
#     "max_num_worker_restarts": 1000,
#     "max_requests_in_flight_per_sampler_worker": 2,
#     "metrics_episode_collection_timeout_s": 60.0,
#     "metrics_num_episodes_for_smoothing": 100,
#     "min_sample_timesteps_per_iteration": 0,
#     "min_time_s_per_iteration": null,
#     "min_train_timesteps_per_iteration": 0,
#     "model": {
#         "_disable_action_flattening": false,
#         "_disable_preprocessor_api": false,
#         "_time_major": false,
#         "_use_default_native_models": -1,
#         "attention_dim": 64,
#         "attention_head_dim": 32,
#         "attention_init_gru_gate_bias": 2.0,
#         "attention_memory_inference": 50,
#         "attention_memory_training": 50,
#         "attention_num_heads": 1,
#         "attention_num_transformer_units": 1,
#         "attention_position_wise_mlp_dim": 32,
#         "attention_use_n_prev_actions": 0,
#         "attention_use_n_prev_rewards": 0,
#         "conv_activation": "relu",
#         "conv_filters": null,
#         "custom_action_dist": null,
#         "custom_model": null,
#         "custom_model_config": {},
#         "custom_preprocessor": null,
#         "dim": 84,
#         "encoder_latent_dim": null,
#         "fcnet_activation": "tanh",
#         "fcnet_hiddens": [
#             256,
#             256
#         ],
#         "framestack": true,
#         "free_log_std": false,
#         "grayscale": false,
#         "lstm_cell_size": 256,
#         "lstm_use_prev_action": false,
#         "lstm_use_prev_action_reward": -1,
#         "lstm_use_prev_reward": false,
#         "max_seq_len": 20,
#         "no_final_linear": false,
#         "post_fcnet_activation": "relu",
#         "post_fcnet_hiddens": [],
#         "use_attention": false,
#         "use_lstm": false,
#         "vf_share_layers": false,
#         "zero_mean": true
#     },
#     "multiagent": {
#         "count_steps_by": "env_steps",
#         "observation_fn": null,
#         "policies": {
#             "default_policy": [
#                 null,
#                 null,
#                 null,
#                 null
#             ]
#         },
#         "policies_to_train": null,
#         "policy_map_cache": -1,
#         "policy_map_capacity": 100,
#         "policy_mapping_fn": "Not serializable object!"
#     },
#     "no_done_at_end": -1,
#     "normalize_actions": true,
#     "num_consecutive_worker_failures_tolerance": 100,
#     "num_cpus_for_driver": 1,
#     "num_cpus_per_learner_worker": 1,
#     "num_cpus_per_worker": 1,
#     "num_envs_per_worker": 1,
#     "num_gpus": 1,
#     "num_gpus_per_learner_worker": 0,
#     "num_gpus_per_worker": 0,
#     "num_learner_workers": 0,
#     "num_sgd_iter": 30,
#     "num_workers": 1,
#     "observation_filter": "NoFilter",
#     "observation_space": null,
#     "off_policy_estimation_methods": {},
#     "offline_sampling": false,
#     "ope_split_batch_by_episode": true,
#     "optimizer": {},
#     "output": null,
#     "output_compress_columns": [
#         "obs",
#         "new_obs"
#     ],
#     "output_config": {},
#     "output_max_file_size": 67108864,
#     "placement_strategy": "PACK",
#     "policy_states_are_swappable": false,
#     "postprocess_inputs": false,
#     "preprocessor_pref": "deepmind",
#     "recreate_failed_workers": false,
#     "remote_env_batch_wait_ms": 0,
#     "remote_worker_envs": false,
#     "render_env": false,
#     "replay_sequence_length": null,
#     "restart_failed_sub_environments": false,
#     "rl_module_spec": null,
#     "rollout_fragment_length": "auto",
#     "sample_async": false,
#     "sample_collector": "Not serializable object!",
#     "sampler_perf_stats_ema_coef": null,
#     "seed": null,
#     "sgd_minibatch_size": 128,
#     "shuffle_buffer_size": 0,
#     "shuffle_sequences": true,
#     "simple_optimizer": -1,
#     "soft_horizon": -1,
#     "sync_filters_on_rollout_workers_timeout_s": 60.0,
#     "synchronize_filters": true,
#     "tf_session_args": {
#         "allow_soft_placement": true,
#         "device_count": {
#             "CPU": 1
#         },
#         "gpu_options": {
#             "allow_growth": true
#         },
#         "inter_op_parallelism_threads": 2,
#         "intra_op_parallelism_threads": 2,
#         "log_device_placement": false
#     },
#     "train_batch_size": 384,
#     "use_critic": true,
#     "use_gae": true,
#     "validate_workers_after_construction": true,
#     "vf_clip_param": 10.0,
#     "vf_loss_coeff": 1.0,
#     "vf_share_layers": -1,
#     "worker_cls": null,
#     "worker_health_probe_timeout_s": 60,
#     "worker_restore_timeout_s": 1800
# }

# %%
algo = config.build()
# Out:
# 2023-10-20 11:05:03,591	INFO algorithm.py:527 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# (RolloutWorker pid=14688) GT Real Time instantiated
# (RolloutWorker pid=14688) GT AI Server instantiated for rtgym
# (RolloutWorker pid=14688) starting up on localhost port 9999
# (RolloutWorker pid=14688) Waiting for a connection
# (RolloutWorker pid=14688) Connection from ('127.0.0.1', 50865)
# (RolloutWorker pid=14688) J:\git\TensorFlowPSX\Py\dragSpaced.csv
# (RolloutWorker pid=14688) Discrete Accel or Brake (cannot left foot) and Discrete Steering 2
# (RolloutWorker pid=14688) 0 1
# 2023-10-20 11:05:24,282	INFO trainable.py:172 -- Trainable.setup took 20.691 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.

# %%
# algo.get_policy().model

# %%
N = 3000

for n in range(N):
    result = algo.train()
    print("Loop: ", n)
    if n % 10 == 0:
        print("Saved", n)
        algo.save()
        
algo.save()
# Out:
# (RolloutWorker pid=14688) reset triggered
# (RolloutWorker pid=14688) 0 8 72
# (RolloutWorker pid=14688) reload save for track : 72
# (RolloutWorker pid=14688) reset triggered
# (RolloutWorker pid=14688) 0 8 72
# (RolloutWorker pid=14688) reload save for track : 72
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.16400690000028817
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# Loop:  0
# Saved 0
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 1.0228194000000101
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) reset triggered
# (RolloutWorker pid=14688) 0 8 72
# (RolloutWorker pid=14688) reload save for track : 72
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.14719430000108247
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# Loop:  1
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.9989002000000085
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) reset triggered
# (RolloutWorker pid=14688) 0 8 72
# (RolloutWorker pid=14688) reload save for track : 72
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.17125820000109115
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# Loop:  2
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.8247448000000048
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) reset triggered
# (RolloutWorker pid=14688) 0 8 72
# (RolloutWorker pid=14688) reload save for track : 72
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.1953147000010773
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# Loop:  3
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.9939970000000073
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) reset triggered
# (RolloutWorker pid=14688) 0 8 72
# (RolloutWorker pid=14688) reload save for track : 72
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.17609640000108584
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# Loop:  4
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.8191454000000107
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) reset triggered
# (RolloutWorker pid=14688) 0 8 72
# (RolloutWorker pid=14688) reload save for track : 72
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.15756009999725507
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# Loop:  5
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.8379925999999784
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) reset triggered
# (RolloutWorker pid=14688) 0 8 72
# (RolloutWorker pid=14688) reload save for track : 72
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.162183399995655
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# Loop:  6
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.8198192999999776
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) reset triggered
# (RolloutWorker pid=14688) 0 8 72
# (RolloutWorker pid=14688) reload save for track : 72
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.14352349999566627
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# Loop:  7
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.8801949999999863
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) reset triggered
# (RolloutWorker pid=14688) 0 8 72
# (RolloutWorker pid=14688) reload save for track : 72
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.1763794999956474
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# Loop:  8
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 1.003365199999962
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.15032269999565528
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) reset triggered
# (RolloutWorker pid=14688) 0 8 72
# (RolloutWorker pid=14688) reload save for track : 72
# Loop:  9
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.8240193000000033
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) reset triggered
# (RolloutWorker pid=14688) 0 8 72
# (RolloutWorker pid=14688) reload save for track : 72
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.1740751999956558
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# Loop:  10
# Saved 10
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.8711008999999592
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) reset triggered
# (RolloutWorker pid=14688) 0 8 72
# (RolloutWorker pid=14688) reload save for track : 72
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.14086619999568484
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# Loop:  11
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.8140659999999684
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.14611479999570065
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) reset triggered
# (RolloutWorker pid=14688) 0 8 72
# (RolloutWorker pid=14688) reload save for track : 72
# Loop:  12
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.8408963999999628
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) reset triggered
# (RolloutWorker pid=14688) 0 8 72
# (RolloutWorker pid=14688) reload save for track : 72
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.1594502999956262
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# Loop:  13
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.8413836999999944
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.15472639999563853
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) reset triggered
# (RolloutWorker pid=14688) 0 8 72
# (RolloutWorker pid=14688) reload save for track : 72
# Loop:  14
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.8386646999999812
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) reset triggered
# (RolloutWorker pid=14688) 0 8 72
# (RolloutWorker pid=14688) reload save for track : 72
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.17529349999568922
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# Loop:  15
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 1.014483499999983
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) reset triggered
# (RolloutWorker pid=14688) 0 8 72
# (RolloutWorker pid=14688) reload save for track : 72
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.16165359999564544
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# Loop:  16
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.8261365999999839
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) reset triggered
# (RolloutWorker pid=14688) 0 8 72
# (RolloutWorker pid=14688) reload save for track : 72
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.16774889999561537
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# Loop:  17
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.8314313000000197
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) reset triggered
# (RolloutWorker pid=14688) 0 8 72
# (RolloutWorker pid=14688) reload save for track : 72
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.14866689999564642
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# Loop:  18
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.8457845999999449
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) reset triggered
# (RolloutWorker pid=14688) 0 8 72
# (RolloutWorker pid=14688) reload save for track : 72
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.17457719999566734
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# Loop:  19
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.8132666999999856
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) reset triggered
# (RolloutWorker pid=14688) 0 8 72
# (RolloutWorker pid=14688) reload save for track : 72
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.1567118999956847
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# Loop:  20
# Saved 20
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 1.2883820999999784
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) reset triggered
# (RolloutWorker pid=14688) 0 8 72
# (RolloutWorker pid=14688) reload save for track : 72
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.14816229999564712
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# Loop:  21
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 1.0044195999999488
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.14907469999565137
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) reset triggered
# (RolloutWorker pid=14688) 0 8 72
# (RolloutWorker pid=14688) reload save for track : 72
# Loop:  22
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.8358463999999799
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) reset triggered
# (RolloutWorker pid=14688) 0 8 72
# (RolloutWorker pid=14688) reload save for track : 72
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.15426879999694165
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# Loop:  23
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.8438318999986905
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) reset triggered
# (RolloutWorker pid=14688) 0 8 72
# (RolloutWorker pid=14688) reload save for track : 72
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.1261131000065916
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# Loop:  24
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.8745208000051434
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.1570619000123088
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) reset triggered
# (RolloutWorker pid=14688) 0 8 72
# (RolloutWorker pid=14688) reload save for track : 72
# Loop:  25
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.8349894000051563
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.13389360001224304
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) reset triggered
# (RolloutWorker pid=14688) 0 8 72
# (RolloutWorker pid=14688) reload save for track : 72
# Loop:  26
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.8691058000051726
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) reset triggered
# (RolloutWorker pid=14688) 0 8 72
# (RolloutWorker pid=14688) reload save for track : 72
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.1563597000123309
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# Loop:  27
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.8194318000051908
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.13947100000575574
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) reset triggered
# (RolloutWorker pid=14688) 0 8 72
# (RolloutWorker pid=14688) reload save for track : 72
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.14195300000653788
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# Loop:  28
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.9129082000051767
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) reset triggered
# (RolloutWorker pid=14688) 0 8 72
# (RolloutWorker pid=14688) reload save for track : 72
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.13241390001223863
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# Loop:  29
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.8713633000052141
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) reset triggered
# (RolloutWorker pid=14688) 0 8 72
# (RolloutWorker pid=14688) reload save for track : 72
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.15891320001230724
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# Loop:  30
# Saved 30
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.8917672000051198
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.14663200001098176
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) reset triggered
# (RolloutWorker pid=14688) 0 8 72
# (RolloutWorker pid=14688) reload save for track : 72
# Loop:  31
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.9858833000065488
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) reset triggered
# (RolloutWorker pid=14688) 0 8 72
# (RolloutWorker pid=14688) reload save for track : 72
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.12417270001094494
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# Loop:  32
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.865132000006497
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) reset triggered
# (RolloutWorker pid=14688) 0 8 72
# (RolloutWorker pid=14688) reload save for track : 72
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.1605257000110214
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# Loop:  33
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.839976900006377
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.13485500001036144
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) reset triggered
# (RolloutWorker pid=14688) 0 8 72
# (RolloutWorker pid=14688) reload save for track : 72
# Loop:  34
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.847116800007143
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) reset triggered
# (RolloutWorker pid=14688) 0 8 72
# (RolloutWorker pid=14688) reload save for track : 72
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.1681217000103743
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# Loop:  35
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.8373135000070988
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.13767600001028768
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) reset triggered
# (RolloutWorker pid=14688) 0 8 72
# (RolloutWorker pid=14688) reload save for track : 72
# Loop:  36
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.8655351000071505
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) reset triggered
# (RolloutWorker pid=14688) 0 8 72
# (RolloutWorker pid=14688) reload save for track : 72
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.12980180000772634
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# Loop:  37
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.8580993000097124
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) reset triggered
# (RolloutWorker pid=14688) 0 8 72
# (RolloutWorker pid=14688) reload save for track : 72
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.14285930000778535
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# Loop:  38
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.8491670000097429
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) reset triggered
# (RolloutWorker pid=14688) 0 8 72
# (RolloutWorker pid=14688) reload save for track : 72
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.13457010000774972
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# Loop:  39
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.8548175000096307
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) reset triggered
# (RolloutWorker pid=14688) 0 8 72
# (RolloutWorker pid=14688) reload save for track : 72
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.12501970000778329
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# Loop:  40
# Saved 40
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.9175666000097635
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.12290660000769549
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) reset triggered
# (RolloutWorker pid=14688) 0 8 72
# (RolloutWorker pid=14688) reload save for track : 72
# Loop:  41
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 1.0205339000096956
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) reset triggered
# (RolloutWorker pid=14688) 0 8 72
# (RolloutWorker pid=14688) reload save for track : 72
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.13970710000774034
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# Loop:  42
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.8531548000097473
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) reset triggered
# (RolloutWorker pid=14688) 0 8 72
# (RolloutWorker pid=14688) reload save for track : 72
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.14678720000779322
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# Loop:  43
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.8395478000096546
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) reset triggered
# (RolloutWorker pid=14688) 0 8 72
# (RolloutWorker pid=14688) reload save for track : 72
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.1367610000077093
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# Loop:  44
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.8739831000098093
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) reset triggered
# (RolloutWorker pid=14688) 0 8 72
# (RolloutWorker pid=14688) reload save for track : 72
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.1260324000068067
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# Loop:  45
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.864984100010588
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) reset triggered
# (RolloutWorker pid=14688) 0 8 72
# (RolloutWorker pid=14688) reload save for track : 72
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.125303200006897
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# Loop:  46
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.8635379000105559
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.15638830000682447
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) reset triggered
# (RolloutWorker pid=14688) 0 8 72
# (RolloutWorker pid=14688) reload save for track : 72
# Loop:  47
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.8187945000106538
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) reset triggered
# (RolloutWorker pid=14688) 0 8 72
# (RolloutWorker pid=14688) reload save for track : 72
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.15039250000688753
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# Loop:  48
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.8589743000105727
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) reset triggered
# (RolloutWorker pid=14688) 0 8 72
# (RolloutWorker pid=14688) reload save for track : 72
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.1257206000068436
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# Loop:  49
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.9124830000105248
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) reset triggered
# (RolloutWorker pid=14688) 0 8 72
# (RolloutWorker pid=14688) reload save for track : 72
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.1276134000067941
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# Loop:  50
# Saved 50
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.8680870000107461
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) reset triggered
# (RolloutWorker pid=14688) 0 8 72
# (RolloutWorker pid=14688) reload save for track : 72
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.12222090000682329
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# Loop:  51
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 1.024843300010616
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) reset triggered
# (RolloutWorker pid=14688) 0 8 72
# (RolloutWorker pid=14688) reload save for track : 72
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.14531830000669288
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# Loop:  52
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.8507465000107004
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) reset triggered
# (RolloutWorker pid=14688) 0 8 72
# (RolloutWorker pid=14688) reload save for track : 72
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.10902120000582727
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# Loop:  53
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.8866876000115553
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) reset triggered
# (RolloutWorker pid=14688) 0 8 72
# (RolloutWorker pid=14688) reload save for track : 72
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.14421080000579423
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# Loop:  54
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.8455986000117264
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.11380400000575719
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) reset triggered
# (RolloutWorker pid=14688) 0 8 72
# (RolloutWorker pid=14688) reload save for track : 72
# Loop:  55
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.8826766000117914
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) reset triggered
# (RolloutWorker pid=14688) 0 8 72
# (RolloutWorker pid=14688) reload save for track : 72
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.12750360000563887
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# Loop:  56
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.8584358000118755
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) reset triggered
# (RolloutWorker pid=14688) 0 8 72
# (RolloutWorker pid=14688) reload save for track : 72
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.1115984000057324
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# Loop:  57
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 1.03179150001165
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.09822290000579414
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) reset triggered
# (RolloutWorker pid=14688) 0 8 72
# (RolloutWorker pid=14688) reload save for track : 72
# Loop:  58
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.9489774000116995
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) reset triggered
# (RolloutWorker pid=14688) 0 8 72
# (RolloutWorker pid=14688) reload save for track : 72
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.13741150000578273
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# Loop:  59
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.8524853000117218
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) reset triggered
# (RolloutWorker pid=14688) 0 8 72
# (RolloutWorker pid=14688) reload save for track : 72
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.11129400000254464
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# Loop:  60
# Saved 60
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.9359020000149485
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) reset triggered
# (RolloutWorker pid=14688) 0 8 72
# (RolloutWorker pid=14688) reload save for track : 72
# ...
# (RolloutWorker pid=14688) reload save for track : 72
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.11191769997822121
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.10569119890715228
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# Loop:  1732
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.9794106999979704
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) reset triggered
# (RolloutWorker pid=14688) 0 8 72
# (RolloutWorker pid=14688) reload save for track : 72
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.11741739997523837
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.06310799891070928
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# Loop:  1733
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.8191496999934316
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) reset triggered
# (RolloutWorker pid=14688) 0 8 72
# (RolloutWorker pid=14688) reload save for track : 72
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.11464719998184592
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.08121669890533667
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# Loop:  1734
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.9823445000001811
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) reset triggered
# (RolloutWorker pid=14688) 0 8 72
# (RolloutWorker pid=14688) reload save for track : 72
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.09390679997886764
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.06127739890507655
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# Loop:  1735
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.847769399995741
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) reset triggered
# (RolloutWorker pid=14688) 0 8 72
# (RolloutWorker pid=14688) reload save for track : 72
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.09553819998109248
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) reset triggered
# (RolloutWorker pid=14688) 0 8 72
# (RolloutWorker pid=14688) reload save for track : 72
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.1526579989513266
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# Loop:  1736
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.9427581999480026
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) reset triggered
# (RolloutWorker pid=14688) 0 8 72
# (RolloutWorker pid=14688) reload save for track : 72
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.13887649893877096
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# Loop:  1737
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.8540008999480051
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) reset triggered
# (RolloutWorker pid=14688) 0 8 72
# (RolloutWorker pid=14688) reload save for track : 72
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.20451279893313767
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# Loop:  1738
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.9969467999471817
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) reset triggered
# (RolloutWorker pid=14688) 0 8 72
# (RolloutWorker pid=14688) reload save for track : 72
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.13364489893137943
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# Loop:  1739
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.8605504999504774
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) reset triggered
# (RolloutWorker pid=14688) 0 8 72
# (RolloutWorker pid=14688) reload save for track : 72
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.2059799989365274
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# Loop:  1740
# Saved 1740
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 1.03634609994333
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) reset triggered
# (RolloutWorker pid=14688) 0 8 72
# (RolloutWorker pid=14688) reload save for track : 72
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.15483529894117964
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# Loop:  1741
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.9828314999467693
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) reset triggered
# (RolloutWorker pid=14688) 0 8 72
# (RolloutWorker pid=14688) reload save for track : 72
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.24929859893018147
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# Loop:  1742
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.945439599949168
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) reset triggered
# (RolloutWorker pid=14688) 0 8 72
# (RolloutWorker pid=14688) reload save for track : 72
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.2179123989335494
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# Loop:  1743
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.9694474999487284
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.1606363989340025
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) reset triggered
# (RolloutWorker pid=14688) 0 8 72
# (RolloutWorker pid=14688) reload save for track : 72
# Loop:  1744
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.8454040999495191
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) reset triggered
# (RolloutWorker pid=14688) 0 8 72
# (RolloutWorker pid=14688) reload save for track : 72
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.1414066991128493
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# Loop:  1745
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.8453107997702318
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) reset triggered
# (RolloutWorker pid=14688) 0 8 72
# (RolloutWorker pid=14688) reload save for track : 72
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.16507529911177699
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# Loop:  1746
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 1.0276281997721526
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.12324319991603261
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) reset triggered
# (RolloutWorker pid=14688) 0 8 72
# (RolloutWorker pid=14688) reload save for track : 72
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.17690459919685964
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# Loop:  1747
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.8889793997659581
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.14227929911430692
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) reset triggered
# (RolloutWorker pid=14688) 0 8 72
# (RolloutWorker pid=14688) reload save for track : 72
# Loop:  1748
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.8527238997703535
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# (RolloutWorker pid=14688) reset triggered
# (RolloutWorker pid=14688) 0 8 72
# (RolloutWorker pid=14688) reload save for track : 72
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 0.18256809911690652
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")
# Loop:  1749
# (RolloutWorker pid=14688) C:\Users\nadir\anaconda3\envs\GTRay2.3.0\lib\site-packages\rtgym\envs\real_time_env.py:376: UserWarning: Time-step timed out. Elapsed since last time-step: 1.0141749997637817
# (RolloutWorker pid=14688)   warnings.warn(f"Time-step timed out. Elapsed since last time-step: {now - self.__t_end}")

# %% [markdown]
# #Works!

# %%
#from ray.rllib.algorithms.algorithm import Algorithm
#algo = Algorithm.from_checkpoint("C:/Users/nadir/ray_results/PPO_gt-rtgym-env-v1_2023-10-14_22-11-44ayp9l_kd/checkpoint_000881")

# %%
# result = algo.train() #single try
